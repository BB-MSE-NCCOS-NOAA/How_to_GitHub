# %% [markdown]
# ### Welcome!
#
# In this notebook we're going to focus on setting up your environment, which at a minimum should have `Git`, `GitHub Desktop`, and an `IDE` of your choosing.
#
# Please note that the process of installing these software on your computer should be accompanied or okay'ed by your IT support staff. You may or may not be installing these, but it helps to know the steps regardless.
#
# ### Objectives:
#
# - Install [Git](https://git-scm.com/)
# - Install [GitHub Desktop](https://desktop.github.com/)
# - Install your IDE

# %% [markdown]
# ### What is Git, and GitHub?
#
# What is `Git`, and how is it different from `GitHub`? Well, [here's](https://git-scm.com/book/en/v2/Getting-Started-What-is-Git%3F) a good definition of the two, but I'll take the good stuff and just put it here for ya.
#
# ##### TL;DR
#
# `Git` vs. `GitHub`… what’s the difference? Simply put, `Git` is a version control system that lets you manage and keep track of your source code history. `GitHub` is a cloud-based hosting service that lets you manage `Git` repositories. If you have open-source projects that use `Git`, then `GitHub` is designed to help you better manage them.
#
# Still interested in learning more? Read on!
#
# ##### Git
#
# First developed back in 2005, `Git` is an extremely popular version control system that is at the heart of a wide variety of high-profile projects. `Git` is installed and maintained on your local system (rather than in the cloud) and gives you a self-contained record of your ongoing programming versions. It can be used completely exclusive of any cloud-hosting service — you don’t even need internet access, except to download it.
#
# Compared to other version control systems, `Git` is responsive, easy to use, and inexpensive (free, actually). `Git` is also specially designed to work well with text files — which, if you think about it, is what code actually is. But one thing that really sets `Git` apart is its branching model. Branching allows you to create independent local branches in your code. This means you can try out new ideas, set aside branches for production work, jump back to earlier branches, and easily delete, merge, and recall branches at the click of a button.
#
# ##### GitHub
#
# In the discussion of `Git` vs. `GitHub`, it’s been said that `GitHub` is to `Git` what Facebook is to your actual face. What’s that mean? Well, it means that while Facebook is kind of like an online face database (of sorts). `GitHub` is designed as a `Git` repository hosting service.
#
# `GitHub` expands upon `Git`’s basic functionality. It presents an extremely intuitive, graphically represented user interface, and provides programmers with built-in control and task-management tools. And because `GitHub` is cloud-based, an individual’s `Git` repositories can be remotely accessed by any authorized person, from any computer, anywhere in the world (provided it has an internet connection).
#
# Through `GitHub`, you can share your code with others, giving them the power to make revisions or edits on your various `Git` branches. This makes it possible for entire teams to coordinate together on single projects in real-time. As changes are introduced, new branches are created, allowing the team to continue to revise the code without overwriting each other’s work. These branches are like copies, and changes made on them do not reflect in the main directories on other users’ machines unless users choose to push/pull the changes to incorporate them. There is also a `GitHub` desktop application available, which offers some additional functionality for experienced developers.

# %% [markdown]
# ### Installation:
#
# Let's start with [Git](https://www.google.com/search?q=git), which will download from here, and then install on our computer.
#
# You might already have Git installed, to check just open up a command terminal (press the Window key, type in `cmd`, press enter). Once open, type in `git`; if you see a list of commands, it's already installed. Else, follow on to install.
#
# ![Git.PNG](attachment:Git.PNG)

# %% [markdown]
# From the website, download `Git`;
#
# ![Download_Git.PNG](attachment:Download_Git.PNG)

# %% [markdown]
# and then go through the process of installing it.
#
# ![Install_Git.PNG](attachment:Install_Git.PNG)
#
# Pretty self explanatory, but, as a sanity check, pull up `cmd` as instructed before and make sure you get a list of helpful commands rather than an error indicating that `Git` is not a recognized command.
#
# Now that your computer has `Git`, you can use it for local version control. This is useful, but we're going to knocking it up a knotch by using `GitHub Desktop`, which provides a GUI for dealing with all things `GitHub`. The steps for downloading and installation are as follows.
#
# Go to the [`GitHub Desktop`](https://desktop.github.com/) website and download the installer:

# %% [markdown]
# ![Github_Desktop_Website.PNG](attachment:Github_Desktop_Website.PNG)

# %% [markdown]
# As with `Git`, go through the installation wizard which is self explanatory; here the only difference is that you'll be prompted to enter in your `GitHub` username and password. This will link your account to your local computer, which makes creating, cloning, merging, forking, etc., much easier and through a GUI.
#
# After you've successfully installed and logged in, a `GitHub` folder will be placed in your Documents folder. At first it will be empty, but next we'll talk about pulling a repo down from `Github`, modifying it, making our first commit, and then pushing it to master. Below you can see I've already pulled some repos from my account to my local machine:
#
# ![Github_Desktop_Local.PNG](attachment:Github_Desktop_Local.PNG)

# %% [markdown]
# But before we do that, let's look at Integrated Development Environments or IDEs. This a fancy string of words describing a software that at a minimum allows you to write, run, and debug code all in the same place. Some examples of IDEs are RStudio Desktop, Pycharm, Jupyter Lab, and Visual Studio Code. Many IDEs will allow you to work in multiple languages and offer plugins for additional support, such as with `GitHub` and `Docker`. Your choice of IDE is likely to be a personal one, as many grow to love their working environment and prefer not to change. [Here's a list of the more popular IDEs](https://geekflare.com/ide-for-programmer/), if you're interested.
#
# I'll let you make that choice; if you code on a regular basis, it's recommended to be working in an IDE for the sake of assistance and convenience. Also, if you choose work in [Vim](https://www.vim.org/) voluntarily, you're a monster.
